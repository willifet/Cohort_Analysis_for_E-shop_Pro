# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('../Data/Dataset_ecommerce.csv')
data.head(10)
# Out:
#   InvoiceNo          InvoiceDate  CustomerID StockCode  Description  Quantity  \
# 0    536365  2010-12-01 08:26:00     17850.0    SC1734  Electronics        65
# 1    536365  2010-12-01 08:26:00     17850.0    SC2088    Furniture        95
# 2    536365  2010-12-01 08:26:00     17850.0    SC3463        Books        78
# 3    536365  2010-12-01 08:26:00     17850.0    SC6228         Toys        15
# 4    536365  2010-12-01 08:26:00     17850.0    SC2149         Toys        50
# 5    536365  2010-12-01 08:26:00     17850.0    SC7895         Toys        41
# 6    536365  2010-12-01 08:26:00     17850.0    SC8608        Books        44
# 7    536366  2010-12-01 08:28:00     17850.0    SC3216         Toys        47
# 8    536366  2010-12-01 08:28:00     17850.0    SC1236  Kitchenware        19
# 9    536367  2010-12-01 08:34:00     13047.0    SC4513    Furniture        55
#
#    UnitPrice        Country
# 0      10.23          Egypt
# 1      19.61           Mali
# 2      61.49           Mali
# 3      24.73   South Africa
# 4      38.83         Rwanda
# 5      45.31   Sierra Leone
# 6      39.31          Benin
# 7      77.35   Burkina Faso
# 8      35.11        Nigeria
# 9       3.21  Cote d'Ivoire

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    406829 non-null  object
#  1   InvoiceDate  406829 non-null  datetime64[ns]
#  2   CustomerID   406829 non-null  float64
#  3   StockCode    406829 non-null  object
#  4   Description  406829 non-null  object
#  5   Quantity     406829 non-null  int64
#  6   UnitPrice    406829 non-null  float64
#  7   Country      406829 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.9+ MB

# %%
data.describe()
# Out:
#           CustomerID       Quantity      UnitPrice
# count  406829.000000  541909.000000  541909.000000
# mean    15287.690570      50.534748      50.476354
# std      1713.600303      28.849367      28.564775
# min     12346.000000       1.000000       1.000000
# 25%     13953.000000      26.000000      25.750000
# 50%     15152.000000      51.000000      50.430000
# 75%     16791.000000      76.000000      75.180000
# max     18287.000000     100.000000     100.000000

# %%
data.describe(include= 'O')
# Out:
#        InvoiceNo          InvoiceDate StockCode       Description  \
# count     541909               541909    541909            541909
# unique     25900                23260      9000                10
# top       573585  2011-10-31 14:41:00    SC2014  Sports Equipment
# freq        1114                 1114        96             54765
#
#               Country
# count          541909
# unique             28
# top     Cote d'Ivoire
# freq            19651

# %%
#Checking Missing data
data[data["CustomerID"].isna()].head(10)
# Out:
#      InvoiceNo          InvoiceDate  CustomerID StockCode       Description  \
# 622     536414  2010-12-01 11:52:00         NaN    SC7308       Kitchenware
# 1443    536544  2010-12-01 14:32:00         NaN    SC3127              Toys
# 1444    536544  2010-12-01 14:32:00         NaN    SC3641       Kitchenware
# 1445    536544  2010-12-01 14:32:00         NaN    SC5252         Cosmetics
# 1446    536544  2010-12-01 14:32:00         NaN    SC1375              Toys
# 1447    536544  2010-12-01 14:32:00         NaN    SC8920             Books
# 1448    536544  2010-12-01 14:32:00         NaN    SC6558         Furniture
# 1449    536544  2010-12-01 14:32:00         NaN    SC3207         Furniture
# 1450    536544  2010-12-01 14:32:00         NaN    SC4675  Sports Equipment
# 1451    536544  2010-12-01 14:32:00         NaN    SC1904  Sports Equipment
#
#       Quantity  UnitPrice        Country
# 622         93      62.55        Senegal
# 1443        86      22.90   Burkina Faso
# 1444         7      72.45        Nigeria
# 1445        39      32.46          Ghana
# 1446        39       3.12   South Africa
# 1447        25      75.53        Algeria
# 1448        85      34.28          Sudan
# 1449        40      89.41  Cote d'Ivoire
# 1450        68      60.70          Sudan
# 1451        33      61.02     Mozambique

# %%
data.isna().sum()
# Out:
# InvoiceNo      0
# InvoiceDate    0
# CustomerID     0
# StockCode      0
# Description    0
# Quantity       0
# UnitPrice      0
# Country        0
# dtype: int64

# %%
#Droping missing value in customerID
data = data.dropna(subset=["CustomerID"])

# %%
data["InvoiceDate"] = pd.to_datetime(data["InvoiceDate"])

# %%
data["TotalPrice"] = data["UnitPrice"] * data["Quantity"]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    406829 non-null  object
#  1   InvoiceDate  406829 non-null  datetime64[ns]
#  2   CustomerID   406829 non-null  float64
#  3   StockCode    406829 non-null  object
#  4   Description  406829 non-null  object
#  5   Quantity     406829 non-null  int64
#  6   UnitPrice    406829 non-null  float64
#  7   Country      406829 non-null  object
#  8   TotalPrice   406829 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 31.0+ MB

# %%
data.head()
# Out:
#   InvoiceNo         InvoiceDate  CustomerID StockCode  Description  Quantity  \
# 0    536365 2010-12-01 08:26:00     17850.0    SC1734  Electronics        65
# 1    536365 2010-12-01 08:26:00     17850.0    SC2088    Furniture        95
# 2    536365 2010-12-01 08:26:00     17850.0    SC3463        Books        78
# 3    536365 2010-12-01 08:26:00     17850.0    SC6228         Toys        15
# 4    536365 2010-12-01 08:26:00     17850.0    SC2149         Toys        50
#
#    UnitPrice       Country  TotalPrice
# 0      10.23         Egypt      664.95
# 1      19.61          Mali     1862.95
# 2      61.49          Mali     4796.22
# 3      24.73  South Africa      370.95
# 4      38.83        Rwanda     1941.50
